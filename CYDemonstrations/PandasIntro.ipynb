# %%
import pandas as pd

# %%
data = pd.read_csv("trends/shopping.csv")

# %%
display(data)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
cols_only = data.columns

cols_only
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
len(cols_only)
# Out:
# 19

# %%
print(data.shape)
# Out:
# (3900, 19)

# %%
print(data.dtypes)
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
data.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# ...

# %%
data.tail(2)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size  Color  Season  Review Rating  \
# 3898                     77   Minnesota    S  Brown  Summer            3.8
# 3899                     81  California    M  Beige  Spring            3.1
#
#      Subscription Status Payment Method Shipping Type Discount Applied  \
# 3898                  No         PayPal       Express               No
# 3899                  No  Bank Transfer  Store Pickup               No
#
#      Promo Code Used  Previous Purchases Preferred Payment Method  \
# 3898              No                  24                    Venmo
# 3899              No                  33                    Venmo
#
#      Frequency of Purchases
# 3898                 Weekly
# 3899              Quarterly

# %%
# do NOT forget the () for .copy method, or it doesn't work the same! 
backup = data.copy()

print(backup)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
cols_dropped = backup.drop(columns=['Category', 'Season'])

display(cols_dropped)
# Out:
#       Customer ID  Age  Gender Item Purchased  Purchase Amount (USD)  \
# 0               1   55    Male         Blouse                     53
# 1               2   19    Male        Sweater                     64
# 2               3   50    Male          Jeans                     73
# 3               4   21    Male        Sandals                     90
# 4               5   45    Male         Blouse                     49
# ...           ...  ...     ...            ...                    ...
# 3895         3896   40  Female         Hoodie                     28
# 3896         3897   52  Female       Backpack                     49
# 3897         3898   46  Female           Belt                     33
# 3898         3899   44  Female          Shoes                     77
# 3899         3900   52  Female        Handbag                     81
#
#            Location Size      Color  Review Rating Subscription Status  \
# ...

# %%
print(data.loc[3])
# Out:
# Customer ID                            4
# Age                                   21
# Gender                              Male
# Item Purchased                   Sandals
# Category                        Footwear
# Purchase Amount (USD)                 90
# Location                    Rhode Island
# Size                                   M
# Color                             Maroon
# Season                            Spring
# Review Rating                        3.5
# Subscription Status                  Yes
# Payment Method                    PayPal
# Shipping Type               Next Day Air
# Discount Applied                     Yes
# Promo Code Used                      Yes
# Previous Purchases                    49
# Preferred Payment Method          PayPal
# Frequency of Purchases            Weekly
# Name: 3, dtype: object

# %%
print(data.iloc[3])
# Out:
# Customer ID                            4
# Age                                   21
# Gender                              Male
# Item Purchased                   Sandals
# Category                        Footwear
# Purchase Amount (USD)                 90
# Location                    Rhode Island
# Size                                   M
# Color                             Maroon
# Season                            Spring
# Review Rating                        3.5
# Subscription Status                  Yes
# Payment Method                    PayPal
# Shipping Type               Next Day Air
# Discount Applied                     Yes
# Promo Code Used                      Yes
# Previous Purchases                    49
# Preferred Payment Method          PayPal
# Frequency of Purchases            Weekly
# Name: 3, dtype: object

# %%
display(data.loc[3:6])
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
# 5            6   46   Male       Sneakers  Footwear                     20
# 6            7   63   Male          Shirt  Clothing                     85
#
#        Location Size      Color  Season  Review Rating Subscription Status  \
# 3  Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4        Oregon    M  Turquoise  Spring            2.7                 Yes
# 5       Wyoming    M      White  Summer            2.9                 Yes
# 6       Montana    M       Gray    Fall            3.2                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 3         PayPal   Next Day Air              Yes             Yes
# 4           Cash  Free Shipping              Yes             Yes
# ...

# %%
display(data.iloc[3:6])
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
# 5            6   46   Male       Sneakers  Footwear                     20
#
#        Location Size      Color  Season  Review Rating Subscription Status  \
# 3  Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4        Oregon    M  Turquoise  Spring            2.7                 Yes
# 5       Wyoming    M      White  Summer            2.9                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 3         PayPal   Next Day Air              Yes             Yes
# 4           Cash  Free Shipping              Yes             Yes
# 5          Venmo       Standard              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# ...

# %%
display(data.iloc[4:6, 3])
# Out:
# 4      Blouse
# 5    Sneakers
# Name: Item Purchased, dtype: object

# %%
display(data.iloc[10, 11:13])
# Out:
# Subscription Status            Yes
# Payment Method         Credit Card
# Name: 10, dtype: object

# %%
second_set = pd.read_csv("trends/new_customers.csv")

display(second_set)
# Out:
#        Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0               0     17850.0      M  Chicago           12.0         16679.0
# 1               1     17850.0      M  Chicago           12.0         16680.0
# 2               2     17850.0      M  Chicago           12.0         16696.0
# 3               3     17850.0      M  Chicago           12.0         16699.0
# 4               4     17850.0      M  Chicago           12.0         16700.0
# ...           ...         ...    ...      ...            ...             ...
# 52950       52950         NaN    NaN      NaN            NaN             NaN
# 52951       52951         NaN    NaN      NaN            NaN             NaN
# 52952       52952         NaN    NaN      NaN            NaN             NaN
# 52953       52953         NaN    NaN      NaN            NaN             NaN
# 52954       52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# ...

# %%
sec_set = second_set.copy()

sec_set_cleaned = sec_set.drop(columns=['Unnamed: 0', 'Tenure_Months', 'Product_SKU', 'Product_Description','Product_Category', 'GST'])

display(sec_set_cleaned)
# Out:
#        CustomerID Gender Location  Transaction_ID Transaction_Date  Quantity  \
# 0         17850.0      M  Chicago         16679.0       2019-01-01       1.0
# 1         17850.0      M  Chicago         16680.0       2019-01-01       1.0
# 2         17850.0      M  Chicago         16696.0       2019-01-01       2.0
# 3         17850.0      M  Chicago         16699.0       2019-01-01       1.0
# 4         17850.0      M  Chicago         16700.0       2019-01-01       1.0
# ...           ...    ...      ...             ...              ...       ...
# 52950         NaN    NaN      NaN             NaN              NaN       NaN
# 52951         NaN    NaN      NaN             NaN              NaN       NaN
# 52952         NaN    NaN      NaN             NaN              NaN       NaN
# 52953         NaN    NaN      NaN             NaN              NaN       NaN
# 52954         NaN    NaN      NaN             NaN              NaN       NaN
#
# ...

# %%
comparison_of_dfs = backup.compare(sec_set_cleaned)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17440\915727634.py in ?()
# ----> 1 comparison_of_dfs = backup.compare(sec_set_cleaned)
#
# c:\Users\jomuf\Documents\CODE KENTUCKY PROJECTS\project2\CYDemonstrations\virtenv\Lib\site-packages\pandas\core\frame.py in ?(self, other, align_axis, keep_shape, keep_equal, result_names)
#    8589         keep_shape: bool = False,
#    8590         keep_equal: bool = False,
#    8591         result_names: Suffixes = ("self", "other"),
#    8592     ) -> DataFrame:
# -> 8593         return super().compare(
#    8594             other=other,
#    8595             align_axis=align_axis,
#    8596             keep_shape=keep_shape,
#
# ...
